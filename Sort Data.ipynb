# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

dict_data = {
    'first': ['kaushal', 'pinkal', 'ananya', 'kartavya'],
    'last': ['khokhar', 'khokhar', 'patel', 'patel'],
    'email':['kaushal.123@gmail.com', 'pinal.123@gmail.com', 'anu.123@gmail.com', 'kartu.123@gmail.com']
}

dict_to_df = pd.DataFrame(dict_data)

# %%
dict_to_df.sort_values(by='last')
# Out:
#       first     last                  email
# 0   kaushal  khokhar  kaushal.123@gmail.com
# 1    pinkal  khokhar    pinal.123@gmail.com
# 2    ananya    patel      anu.123@gmail.com
# 3  kartavya    patel    kartu.123@gmail.com

# %%
dict_to_df.sort_values(by='last', ascending=False)
# Out:
#       first     last                  email
# 2    ananya    patel      anu.123@gmail.com
# 3  kartavya    patel    kartu.123@gmail.com
# 0   kaushal  khokhar  kaushal.123@gmail.com
# 1    pinkal  khokhar    pinal.123@gmail.com

# %%
# sorting with two values
dict_to_df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#       first     last                  email
# 3  kartavya    patel    kartu.123@gmail.com
# 2    ananya    patel      anu.123@gmail.com
# 1    pinkal  khokhar    pinal.123@gmail.com
# 0   kaushal  khokhar  kaushal.123@gmail.com

# %%
# sorting with two values with different sorting condition
dict_to_df.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#       first     last                  email
# 2    ananya    patel      anu.123@gmail.com
# 3  kartavya    patel    kartu.123@gmail.com
# 0   kaushal  khokhar  kaushal.123@gmail.com
# 1    pinkal  khokhar    pinal.123@gmail.com

# %%
dict_to_df.sort_index()
# Out:
#       first     last                  email
# 0   kaushal  khokhar  kaushal.123@gmail.com
# 1    pinkal  khokhar    pinal.123@gmail.com
# 2    ananya    patel      anu.123@gmail.com
# 3  kartavya    patel    kartu.123@gmail.com

# %%
dict_to_df['last'].sort_values()
# Out:
# 0    khokhar
# 1    khokhar
# 2      patel
# 3      patel
# Name: last, dtype: object

# %%
# 10 largert salary
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
# 10 largert salary
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %%
# 5 smallest salary
df.nsmallest(5, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 280         I am a developer by profession      Yes
# 293         I am a developer by profession      Yes
# 722         I am a developer by profession       No
# 1105        I am a developer by profession       No
# 1501        I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 280                                   Less than once per year
# 293                                   Less than once per year
# 722         Less than once a month but more than once per ...
# 1105                                                    Never
# 1501                               Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 280         OSS is, on average, of HIGHER quality than pro...
# 293         OSS is, on average, of HIGHER quality than pro...
# ...
